# %% [markdown]
# <div style="color:red;background-color:lime;padding:3%;border-radius:150px 150px;font-size:2em;text-align:center">Data analysis with-LR-DT-RF-and-SVM-99.6% AUC</div>

# %% [markdown]
# ![](https://j.gifs.com/76kDrQ.gif)

# %% [markdown]
# # About Dataset
#
# Machine Predictive Maintenance Classification Dataset Since real predictive maintenance datasets are generally difficult to obtain and in particular difficult to publish, we present and provide a synthetic dataset that reflects real predictive maintenance encountered in the industry to the best of our knowledge.
#
#
# The dataset consists of 10 000 data points stored as rows with 14 features in columns
#
# Important :
#
# There are two Targets - Do not make the mistake of using one of them as feature, as it will lead to leakage. Target : Failure or Not Failure Type : Type of Failure
#
# 1.Type: Indicates the type of the tool (e.g., L, M, H).
#
# 2.Air temperature [°C]: The temperature of the surrounding air in degrees Celsius.
#
# 3.Process temperature [°C]: The temperature during the manufacturing process in degrees Celsius.
#
# 4.Rotational speed [rpm]: The speed at which the tool is rotating, measured in revolutions per minute.
#
# 5.Torque [Nm]: The torque applied during the manufacturing process, measured in Newton meters.
#
# 6.Tool wear [min]: The amount of wear on the tool, measured in minutes.
#
# 7.Target: The target variable indicating whether the process was successful (0) or resulted in a failure (1).
#
# 8.Failure Type: The type of failure that occurred during the manufacturing process. If no failure occurred, this field is "No Failure".
#
# 9.Temperature difference [°C]: The difference between the process temperature and the air temperature, measured in degrees Celsius.

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
#Default theme
sns.set_theme(palette='tab10',
              font='Lucida Calligraphy',
              font_scale=1.5,
              rc=None)

import matplotlib
matplotlib.rcParams.update({'font.size': 15})
plt.style.use('dark_background')

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
df=pd.read_csv("predictive_maintenance.csv")
df = df.drop(["UDI","Product ID"],axis=1)
df.sample(30).style.set_properties(
    **{
        'background-color': 'Brown',
        'color': 'white',
        'border-color': 'White'
    })
# Out:
# <style type="text/css">
# #T_7247d_row0_col0, #T_7247d_row0_col1, #T_7247d_row0_col2, #T_7247d_row0_col3, #T_7247d_row0_col4, #T_7247d_row0_col5, #T_7247d_row0_col6, #T_7247d_row0_col7, #T_7247d_row1_col0, #T_7247d_row1_col1, #T_7247d_row1_col2, #T_7247d_row1_col3, #T_7247d_row1_col4, #T_7247d_row1_col5, #T_7247d_row1_col6, #T_7247d_row1_col7, #T_7247d_row2_col0, #T_7247d_row2_col1, #T_7247d_row2_col2, #T_7247d_row2_col3, #T_7247d_row2_col4, #T_7247d_row2_col5, #T_7247d_row2_col6, #T_7247d_row2_col7, #T_7247d_row3_col0, #T_7247d_row3_col1, #T_7247d_row3_col2, #T_7247d_row3_col3, #T_7247d_row3_col4, #T_7247d_row3_col5, #T_7247d_row3_col6, #T_7247d_row3_col7, #T_7247d_row4_col0, #T_7247d_row4_col1, #T_7247d_row4_col2, #T_7247d_row4_col3, #T_7247d_row4_col4, #T_7247d_row4_col5, #T_7247d_row4_col6, #T_7247d_row4_col7, #T_7247d_row5_col0, #T_7247d_row5_col1, #T_7247d_row5_col2, #T_7247d_row5_col3, #T_7247d_row5_col4, #T_7247d_row5_col5, #T_7247d_row5_col6, #T_7247d_row5_col7, #T_7247d_row6_col0, #T_7247d_row6_col1, #T_7247d_row6_col2, #T_7247d_row6_col3, #T_7247d_row6_col4, #T_7247d_row6_col5, #T_7247d_row6_col6, #T_7247d_row6_col7, #T_7247d_row7_col0, #T_7247d_row7_col1, #T_7247d_row7_col2, #T_7247d_row7_col3, #T_7247d_row7_col4, #T_7247d_row7_col5, #T_7247d_row7_col6, #T_7247d_row7_col7, #T_7247d_row8_col0, #T_7247d_row8_col1, #T_7247d_row8_col2, #T_7247d_row8_col3, #T_7247d_row8_col4, #T_7247d_row8_col5, #T_7247d_row8_col6, #T_7247d_row8_col7, #T_7247d_row9_col0, #T_7247d_row9_col1, #T_7247d_row9_col2, #T_7247d_row9_col3, #T_7247d_row9_col4, #T_7247d_row9_col5, #T_7247d_row9_col6, #T_7247d_row9_col7, #T_7247d_row10_col0, #T_7247d_row10_col1, #T_7247d_row10_col2, #T_7247d_row10_col3, #T_7247d_row10_col4, #T_7247d_row10_col5, #T_7247d_row10_col6, #T_7247d_row10_col7, #T_7247d_row11_col0, #T_7247d_row11_col1, #T_7247d_row11_col2, #T_7247d_row11_col3, #T_7247d_row11_col4, #T_7247d_row11_col5, #T_7247d_row11_col6, #T_7247d_row11_col7, #T_7247d_row12_col0, #T_7247d_row12_col1, #T_7247d_row12_col2, #T_7247d_row12_col3, #T_7247d_row12_col4, #T_7247d_row12_col5, #T_7247d_row12_col6, #T_7247d_row12_col7, #T_7247d_row13_col0, #T_7247d_row13_col1, #T_7247d_row13_col2, #T_7247d_row13_col3, #T_7247d_row13_col4, #T_7247d_row13_col5, #T_7247d_row13_col6, #T_7247d_row13_col7, #T_7247d_row14_col0, #T_7247d_row14_col1, #T_7247d_row14_col2, #T_7247d_row14_col3, #T_7247d_row14_col4, #T_7247d_row14_col5, #T_7247d_row14_col6, #T_7247d_row14_col7, #T_7247d_row15_col0, #T_7247d_row15_col1, #T_7247d_row15_col2, #T_7247d_row15_col3, #T_7247d_row15_col4, #T_7247d_row15_col5, #T_7247d_row15_col6, #T_7247d_row15_col7, #T_7247d_row16_col0, #T_7247d_row16_col1, #T_7247d_row16_col2, #T_7247d_row16_col3, #T_7247d_row16_col4, #T_7247d_row16_col5, #T_7247d_row16_col6, #T_7247d_row16_col7, #T_7247d_row17_col0, #T_7247d_row17_col1, #T_7247d_row17_col2, #T_7247d_row17_col3, #T_7247d_row17_col4, #T_7247d_row17_col5, #T_7247d_row17_col6, #T_7247d_row17_col7, #T_7247d_row18_col0, #T_7247d_row18_col1, #T_7247d_row18_col2, #T_7247d_row18_col3, #T_7247d_row18_col4, #T_7247d_row18_col5, #T_7247d_row18_col6, #T_7247d_row18_col7, #T_7247d_row19_col0, #T_7247d_row19_col1, #T_7247d_row19_col2, #T_7247d_row19_col3, #T_7247d_row19_col4, #T_7247d_row19_col5, #T_7247d_row19_col6, #T_7247d_row19_col7, #T_7247d_row20_col0, #T_7247d_row20_col1, #T_7247d_row20_col2, #T_7247d_row20_col3, #T_7247d_row20_col4, #T_7247d_row20_col5, #T_7247d_row20_col6, #T_7247d_row20_col7, #T_7247d_row21_col0, #T_7247d_row21_col1, #T_7247d_row21_col2, #T_7247d_row21_col3, #T_7247d_row21_col4, #T_7247d_row21_col5, #T_7247d_row21_col6, #T_7247d_row21_col7, #T_7247d_row22_col0, #T_7247d_row22_col1, #T_7247d_row22_col2, #T_7247d_row22_col3, #T_7247d_row22_col4, #T_7247d_row22_col5, #T_7247d_row22_col6, #T_7247d_row22_col7, #T_7247d_row23_col0, #T_7247d_row23_col1, #T_7247d_row23_col2, #T_7247d_row23_col3, #T_7247d_row23_col4, #T_7247d_row23_col5, #T_7247d_row23_col6, #T_7247d_row23_col7, #T_7247d_row24_col0, #T_7247d_row24_col1, #T_724 ...
#   background-color: Brown;
#   color: white;
#   border-color: White;
# }
# </style>
# <table id="T_7247d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7247d_level0_col0" class="col_heading level0 col0" >Type</th>
#       <th id="T_7247d_level0_col1" class="col_heading level0 col1" >Air temperature [K]</th>
#       <th id="T_7247d_level0_col2" class="col_heading level0 col2" >Process temperature [K]</th>
#       <th id="T_7247d_level0_col3" class="col_heading level0 col3" >Rotational speed [rpm]</th>
#       <th id="T_7247d_level0_col4" class="col_heading level0 col4" >Torque [Nm]</th>
#       <th id="T_7247d_level0_col5" class="col_heading level0 col5" >Tool wear [min]</th>
#       <th id="T_7247d_level0_col6" class="col_heading level0 col6" >Target</th>
#       <th id="T_7247d_level0_col7" class="col_heading level0 col7" >Failure Type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7247d_level0_row0" class="row_heading level0 row0" >9759</th>
#       <td id="T_7247d_row0_col0" class="data row0 col0" >L</td>
#       <td id="T_7247d_row0_col1" class="data row0 col1" >298.500000</td>
#       <td id="T_7247d_row0_col2" class="data row0 col2" >309.700000</td>
#       <td id="T_7247d_row0_col3" class="data row0 col3" >1613</td>
#       <td id="T_7247d_row0_col4" class="data row0 col4" >36.700000</td>
#       <td id="T_7247d_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_7247d_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_7247d_row0_col7" class="data row0 col7" >No Failure</td>
#     </tr>
#     <tr>
#       <th id="T_7247d_level0_row1" class="row_heading level0 row1" >7100</th>
#       <td id="T_7247d_row1_col0" class="data row1 col0" >L</td>
#       <td id="T_7247d_row1_col1" class="data row1 col1" >300.700000</td>
#       <td id="T_7247d_row1_col2" class="data row1 col2" >310.200000</td>
#       <td id="T_7247d_row1_col3" class="data row1 col3" >1569</td>
#       <td id="T_7247d_row1_col4" class="data row1 col4" >32.800000</td>
#       <td id="T_7247d_row1_col5" class="data row1 col5" >31</td>
#       <td id="T_7247d_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_7247d_row1_col7" class="data row1 col7" >No Failure</td>
#     </tr>
#     <tr>
#       <th id="T_7247d_level0_row2" class="row_heading level0 row2" >322</th>
#       <td id="T_7247d_row2_col0" class="data row2 col0" >L</td>
#       <td id="T_7247d_row2_col1" class="data row2 col1" >297.800000</td>
#       <td id="T_7247d_row2_col2" class="data row2 col2" >308.500000</td>
#       <td id="T_7247d_row2_col3" class="data row2 col3" >1448</td>
#       <td id="T_7247d_row2_col4" class="data row2 col4" >40.000000</td>
#       <td id="T_7247d_row2_col5" class="data row2 col5" >192</td>
#       <td id="T_7247d_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_7247d_row2_col7" class="data row2 col7" >No Failure</td>
#     </tr>
#     <tr>
#       <th id="T_7247d_level0_row3" class="row_heading level0 row3" >695</th>
#       <td id="T_7247d_row3_col0" class="data row3 col0" >L</td>
#       <td id="T_7247d_row3

# %%
## Converting temperature in centigrate from Kelvin [1 K = -272.15 °C  ] 

df["Air temperature [K]"] = df["Air temperature [K]"] - 272.15
df["Process temperature [K]"] = df["Process temperature [K]"] - 272.15

# Renaming temperature in Centigrate(°C) from Kelvin (K)
df.rename(columns={"Air temperature [K]" : "Air temperature [°C]","Process temperature [K]" : "Process temperature [°C]"},inplace=True)

# %%
df["Temperature difference [°C]"] = df["Process temperature [°C]"] - df["Air temperature [°C]"]
df.sample(6)
# Out:
#      Type  Air temperature [°C]  Process temperature [°C]  \
# 1985    L                 25.95                     35.55
# 7903    L                 28.65                     40.15
# 4993    L                 31.65                     40.75
# 3976    H                 30.15                     39.25
# 4873    M                 31.55                     40.25
# 8012    M                 28.75                     39.85
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  \
# 1985                    1537         40.8              169       0
# 7903                    1435         44.8              134       0
# 4993                    1819         23.7               16       0
# 3976                    1372         46.0               86       0
# 4873                    1474         38.8              139       0
# 8012                    1375         56.1              182       0
#
#      Failure Type  Temperature difference [°C]
# 1985   No Failure                          9.6
# 7903   No Failure                         11.5
# 4993   No Failure                          9.1
# 3976   No Failure                          9.1
# 4873   No Failure                          8.7
# 8012   No Failure                         11.1

# %%
display(df.shape)
display(df.size)
# Out:
# (10000, 9)
# 90000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Type                         10000 non-null  object
#  1   Air temperature [°C]         10000 non-null  float64
#  2   Process temperature [°C]     10000 non-null  float64
#  3   Rotational speed [rpm]       10000 non-null  int64
#  4   Torque [Nm]                  10000 non-null  float64
#  5   Tool wear [min]              10000 non-null  int64
#  6   Target                       10000 non-null  int64
#  7   Failure Type                 10000 non-null  object
#  8   Temperature difference [°C]  10000 non-null  float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 703.3+ KB

# %%
df.columns
# Out:
# Index(['Type', 'Air temperature [°C]', 'Process temperature [°C]',
#        'Rotational speed [rpm]', 'Torque [Nm]', 'Tool wear [min]', 'Target',
#        'Failure Type', 'Temperature difference [°C]'],
#       dtype='object')

# %%
for col in df[['Type','Target','Failure Type']]:
    print(df[col].value_counts()) 
    print("****"*8)
# Out:
# Type
# L    6000
# M    2997
# H    1003
# Name: count, dtype: int64
# ********************************
# Target
# 0    9661
# 1     339
# Name: count, dtype: int64
# ********************************
# Failure Type
# No Failure                  9652
# Heat Dissipation Failure     112
# Power Failure                 95
# Overstrain Failure            78
# Tool Wear Failure             45
# Random Failures               18
# Name: count, dtype: int64
# ********************************
